# %% [markdown]
# # Capstone Project Overview
#
# In this lesson, you will learn about the capstone project, its requirements, and how to effectively plan your project. By the end of this lesson, you will be able to outline a project plan, identify necessary resources, and set realistic timelines.

# %% [markdown]
# ## Learning Objectives
# - Understand the requirements of the capstone project.
# - Outline a project plan with clear objectives.
# - Identify resources needed for project execution.
# - Recognize the importance of project planning.
# - Set realistic timelines for project milestones.

# %% [markdown]
# ## Why This Matters
#
# Effective project planning is crucial for the successful execution of any project. It ensures that all aspects are considered and organized, which helps in preventing scope creep and missed deadlines.

# %% [markdown]
# ## Project Planning
# ### Explanation
# Project planning involves defining the objectives, scope, and timeline of a project. It ensures that all necessary steps are organized and accounted for.

# %%
# Example code for defining project objectives
objectives = ['Define project scope', 'Set milestones', 'Allocate resources']
print('Project Objectives:', objectives)

# %% [markdown]
# ### Micro-Exercise: Outline Project Objectives
#
# # List the main objectives of your capstone project.
# # Hint: Think about what you want your project to achieve.

# %%
# Define your project objectives here
project_objectives = []
# Add your objectives below
# project_objectives.append('Your objective here')
print('Project Objectives:', project_objectives)

# %% [markdown]
# ## Resource Identification
# ### Explanation
# Resource identification includes recognizing the human and technical resources required to complete the project. This helps in allocating the right tools and personnel.

# %%
# Example code for listing resources
resources = ['Python libraries', 'Development team', 'Testing tools']
print('Resources Needed:', resources)

# %% [markdown]
# ### Micro-Exercise: Identify Resources
#
# # Identify the resources you will need for your project.
# # Hint: Consider both human and technical resources.

# %%
# Define your project resources here
project_resources = []
# Add your resources below
# project_resources.append('Your resource here')
print('Project Resources:', project_resources)

# %% [markdown]
# ## Examples
# ### Example 1: Building a Customer Support AI Agent
# This example demonstrates how to outline a project plan for creating an AI agent that can handle customer inquiries effectively.

# %%
# Example code for defining project objectives for a Customer Support AI Agent
objectives = ['Automate responses', 'Improve response time', 'Track customer satisfaction']
print('Customer Support AI Objectives:', objectives)

# %% [markdown]
# ### Example 2: Developing a Task Management Tool
# This example illustrates how to identify resources needed for developing a task management tool that integrates with existing workflows.

# %%
# Example code for listing resources for a Task Management Tool
resources = ['Python libraries', 'Development team', 'Testing tools']
print('Task Management Tool Resources:', resources)

# %% [markdown]
# ## Main Exercise: Capstone Project Planning Exercise
# Create a comprehensive project plan for your capstone project, including objectives, timelines, and resources needed.

# %%
# Define your project plan here
project_plan = {
    'objectives': [],
    'timeline': {},
    'resources': []
}
print('Project Plan:', project_plan)

# %% [markdown]
# ## Common Mistakes
# - Not planning adequately, leading to scope creep and missed deadlines.
# - Failing to identify all necessary resources, resulting in project delays.

# %% [markdown]
# ## Recap & Next Steps
# In this lesson, we covered the importance of project planning and resource identification. You should now have a clearer understanding of how to approach your capstone project. In the next lesson, we will dive deeper into specific project management techniques.
