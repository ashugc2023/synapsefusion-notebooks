# %% [markdown]
# # Capstone Project Overview
#
# In this lesson, we will introduce the capstone project, outlining its requirements and expectations. You will learn how to plan your projects effectively, ensuring you understand the scope, deliverables, and timeline.

# %% [markdown]
# ## Learning Objectives
# - Understand the project requirements and scope.
# - Plan the project steps and timeline.
# - Identify resources needed for project completion.

# %% [markdown]
# ## Why This Matters
#
# Effective project planning is crucial for successful project execution and management. It helps in defining the scope, objectives, and timeline, ensuring that all team members are aligned and resources are utilized efficiently.

# %% [markdown]
# ## Project Planning
# ### Explanation
# Project planning involves defining the scope, objectives, and timeline of a project to ensure successful execution.
#
# ### Why It Matters
# Effective project planning is crucial for successful project execution and management.

# %%
# Example: Defining Project Scope
ProjectScope = 'Deploy a web application using AWS services'
print('Project Scope:', ProjectScope)

# %% [markdown]
# ### Micro-Exercise: Define Your Project Scope
# Define the scope of your capstone project, including the main objectives.

# %%
# Define your project scope here
ProjectScope = ''  # Fill in your project scope

# %% [markdown]
# ## Resource Identification
# ### Explanation
# Resource identification is the process of determining the necessary human and technical resources required to complete a project.
#
# ### Why It Matters
# Identifying the necessary resources ensures that the project can be completed efficiently and effectively.

# %%
# Example: Identifying Resources
RequiredResources = ['AWS Account', 'Development Team', 'Testing Tools']
print('Required Resources:', RequiredResources)

# %% [markdown]
# ### Micro-Exercise: List Your Project Deliverables
# List the deliverables for your capstone project, detailing what will be produced.

# %%
# List your project deliverables here
Deliverables = []  # Fill in your project deliverables

# %% [markdown]
# ## Examples
# ### Example 1: Defining Project Scope
# This example demonstrates how to define the scope of a web application deployment project using AWS CLI.
# ```python
# # Define project scope
# ProjectScope = 'Deploy a web application using AWS services'
# print('Project Scope:', ProjectScope)
# ```
#
# ### Example 2: Creating a Project Timeline
# This example shows how to create a project timeline with milestones for the deployment of a web application.
# ```python
# # Create project timeline
# ProjectTimeline = {'Milestone 1': 'Setup AWS account', 'Milestone 2': 'Deploy application'}
# print('Project Timeline:', ProjectTimeline)
# ```

# %% [markdown]
# ## Main Exercise: Comprehensive Project Plan Creation
# Create a detailed project plan for your capstone project, including scope, timeline, and resource identification.

# %%
# Create your project plan here
ProjectPlan = {
    'Scope': '',  # Define your project scope
    'Timeline': {},  # Define your project timeline
    'Resources': []  # List your required resources
}
print('Project Plan:', ProjectPlan)

# %% [markdown]
# ## Common Mistakes
# - Not planning the project effectively, leading to scope creep and missed deadlines.
# - Failing to identify all necessary resources, which can hinder project progress.

# %% [markdown]
# ## Recap & Next Steps
# In this lesson, we covered the importance of project planning and resource identification. You should now have a clear understanding of how to define your project scope, create a timeline, and identify necessary resources. In the next lesson, we will dive deeper into executing your project plan.
