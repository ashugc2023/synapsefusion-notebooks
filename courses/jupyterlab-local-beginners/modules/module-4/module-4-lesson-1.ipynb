# %% [markdown]
# # Creating Project Folders
#
# In this lesson, you will learn how to create and manage project folders in JupyterLab. A well-structured folder system is essential for keeping your data science projects organized and accessible.
#
# ## Learning Objectives
# - Create a new folder in JupyterLab.
# - Organize files into appropriate folders.
# - Delete unnecessary folders to maintain clarity.
# - Understand the importance of folder structure in project management.
# - Apply best practices for naming folders.

# %% [markdown]
# ## Why This Matters
#
# Creating a well-organized folder structure is crucial for managing your data science projects effectively. It allows you to locate files quickly, collaborate with others seamlessly, and maintain clarity throughout your project lifecycle.

# %% [markdown]
# ## Folder Creation
# ### Explanation
# Folder creation in JupyterLab allows users to systematically organize their project files, making it easier to locate and manage them.
#
# ### Why It Matters
# Creating folders helps in organizing your project files systematically, making it easier to locate and manage them.

# %%
# Example: Creating a new folder in JupyterLab
# To create a new folder, you can use the file browser or command line.
# Here is how to create a folder using the file browser:

# 1. Right-click in the file browser area.
# 2. Select 'New Folder'.
# 3. Name your folder (e.g., 'MyDataScienceProject').

# %% [markdown]
# ## Micro-Exercise 1
# ### Task Description
# Create a new folder for your project in JupyterLab.

# %%
# Starter Code for Micro-Exercise 1
# Create a new folder for your project in JupyterLab.
# Use the file browser to create a folder named 'MyProject'.

# %% [markdown]
# ## File Organization
# ### Explanation
# Proper file organization involves categorizing files into relevant folders, which enhances navigation and collaboration.
#
# ### Why It Matters
# Proper organization of files ensures that you can efficiently navigate your project and collaborate with others.

# %%
# Example: Organizing files into subfolders
# After creating a main project folder, you can create subfolders for better organization.
# For example:

# 1. Create subfolders: 'data', 'notebooks', 'results' within 'MyDataScienceProject'.
# 2. Move existing files into these subfolders.

# %% [markdown]
# ## Micro-Exercise 2
# ### Task Description
# Move an existing notebook into the new folder.

# %%
# Starter Code for Micro-Exercise 2
# Move an existing notebook into the new folder named 'MyProject'.
# You can drag and drop the file in the file browser.

# %% [markdown]
# ## Examples
# ### Example 1: Creating a Main Project Folder
# This example demonstrates how to create a main folder for your project using the file browser.
#
# ```python
# # Create a new folder named 'MyDataScienceProject' in JupyterLab.
# # 1. Right-click in the file browser area.
# # 2. Select 'New Folder'.
# # 3. Name the folder 'MyDataScienceProject'.
# ```
#
# ### Example 2: Organizing Files into Subfolders
# This example shows how to create subfolders for data, notebooks, and results within the main project folder.
#
# ```python
# # Create subfolders: 'data', 'notebooks', 'results' within 'MyDataScienceProject'.
# # 1. Right-click on 'MyDataScienceProject'.
# # 2. Select 'New Folder' for each subfolder.
# # 3. Name them accordingly.
# ```

# %% [markdown]
# ## Main Exercise
# ### Exercise Description
# In this exercise, you will create a main project folder and organize your files into appropriate subfolders.
#
# ### Steps:
# 1. Create a main project folder named 'MyDataScienceProject'.
# 2. Within this folder, create subfolders for 'data', 'notebooks', and 'results'.
# 3. Move any existing files into the appropriate subfolders.
#
# ### Expected Outcomes:
# - A structured folder system that organizes your project files.
# - Clear understanding of folder management in JupyterLab.

# %%
# Code to create the main project folder and subfolders
# Create a main project folder
# 1. Create a folder named 'MyDataScienceProject'.
# 2. Create subfolders: 'data', 'notebooks', 'results'.

# %% [markdown]
# ## Common Mistakes
# - Not naming folders clearly, leading to confusion.
# - Creating too many nested folders, which complicates navigation.

# %% [markdown]
# ## Recap
# In this lesson, you learned how to create and manage project folders in JupyterLab. A well-structured folder system is essential for keeping your data science projects organized. Next, we will explore how to manage files within these folders effectively.
