# %% [markdown]
# # Managing Files and Notebooks
#
# ## Learning Objectives
# - Open and close files in JupyterLab.
# - Rename files to reflect their content.
# - Delete files that are no longer needed.
# - Understand the importance of file management in data science.
# - Apply best practices for maintaining an organized workspace.

# %% [markdown]
# ## Why This Matters
#
# Effective file and notebook management is crucial in data science. It allows you to keep your workspace tidy, making it easier to find and work with your files. Proper management prevents loss of important data and enhances productivity.

# %% [markdown]
# ### Concept 1: File Management
#
# File management involves organizing and maintaining files in a way that makes them easy to access and use. In JupyterLab, this includes opening and closing files properly.
#
# #### Why It Matters
# Effective file management allows you to keep your workspace tidy and makes it easier to find and work with your files.

# %%
# Example: Opening and Closing a Notebook
# To open a notebook, simply click on it in the file browser.
# After making changes, remember to save your work before closing.

# Open a notebook
# Make changes
# Close the notebook

# %% [markdown]
# #### Micro-Exercise 1
#
# ## Open and Close a Notebook
# Open a notebook, make a small change, and then close it.

# %%
# Starter Code for Micro-Exercise 1
# Open a notebook named 'example_notebook.ipynb'
# Make a small change, such as adding a comment
# Save and close the notebook

# Open the notebook
# Make a change
# Save the notebook

# %% [markdown]
# ### Concept 2: Notebook Management
#
# Notebook management refers to the practices of renaming and deleting notebooks to ensure that your work is organized and that you do not lose important data.
#
# #### Why It Matters
# Managing notebooks properly ensures that your work is saved and organized, preventing loss of important data.

# %%
# Example: Renaming a File
# To rename a notebook, right-click on the file in the file browser and select 'Rename'.
# Enter a new name that reflects the content of the notebook.

# %% [markdown]
# #### Micro-Exercise 2
#
# ## Rename a Notebook
# Rename an existing notebook to reflect its content. Use the right-click context menu to find the rename option.

# %%
# Starter Code for Micro-Exercise 2
# Assume the notebook is named 'old_notebook.ipynb'
# Rename it to 'new_notebook.ipynb'

# Right-click on 'old_notebook.ipynb' and select 'Rename'
# Enter 'new_notebook.ipynb'

# %% [markdown]
# ## Examples
#
# ### Example 1: Opening and Closing a Notebook
# This example demonstrates how to open a notebook, make changes, and close it properly.
#
# ```python
# # Open a notebook
# # Make changes
# # Close the notebook
# ```
#
# ### Example 2: Renaming a File
# This example shows how to rename a file to better reflect its content.
#
# ```python
# # Rename the notebook using the JupyterLab interface.
# ```

# %% [markdown]
# ## Micro-Exercises
#
# ### Exercise 1: Rename a Notebook
# # Rename an existing notebook to reflect its content.
#
# ### Exercise 2: Delete a File
# # Delete a file that is no longer needed. Ensure you have backed up any important data before deletion.

# %% [markdown]
# ## Main Exercise
# In this exercise, you will:
# 1. Open a notebook.
# 2. Make a small change.
# 3. Rename it to better reflect its content.
# 4. Delete a file that is no longer needed.

# %%
# Main Exercise Code
# Open a notebook
# Make a change
# Rename the notebook
# Delete an unnecessary file

# Open the notebook
# Make a change
# Rename the notebook
# Delete the file

# %% [markdown]
# ## Common Mistakes
# - Not saving changes before closing files.
# - Deleting important files without backup.

# %% [markdown]
# ## Recap
# In this lesson, we covered how to manage files and notebooks in JupyterLab. You learned how to open, rename, and delete files, as well as the importance of maintaining an organized workspace. In the next lesson, we will explore data visualization techniques in JupyterLab.
