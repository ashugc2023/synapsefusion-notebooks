# %% [markdown]
# # Navigating the JupyterLab Interface
#
# ## Learning Objectives
# - Understand the layout of JupyterLab.
# - Use the file browser to manage files.
# - Open and manage notebooks effectively.

# %% [markdown]
# ## Why This Matters
#
# Navigating the JupyterLab interface is crucial for efficient local development and data science projects. A well-organized workspace allows you to focus on your coding and analysis without getting lost in your files.

# %% [markdown]
# ### Key Concept: File Browser
# The file browser allows users to view, organize, and manage files and directories within JupyterLab. It is essential for accessing notebooks and other project files.

# %%
# Example: Opening the file browser
# The file browser is usually located on the left side of the JupyterLab interface.
# You can navigate through your directories and files here.

# %% [markdown]
# #### Micro-Exercise 1
# - **Task:** Open the file browser and create a new folder named 'My Project'.
# - **Hint:** Right-click in the file browser area.

# %%
# Starter code for Micro-Exercise 1
# Open the file browser and create a new folder named 'My Project'.
# This can be done by right-clicking in the file browser.

# %% [markdown]
# ### Key Concept: Notebook Interface
# The notebook interface is where users write and execute code, add text, and visualize data. It includes features like cells for code and markdown, making it versatile for data science tasks.

# %%
# Example: Creating a new notebook
# To create a new notebook, go to the file menu and select 'New Notebook'.
# You can choose the kernel (e.g., Python) for your notebook.

# %% [markdown]
# #### Micro-Exercise 2
# - **Task:** Open a new notebook and rename it to 'My First Notebook'.
# - **Hint:** Use the file browser to find your notebook.

# %%
# Starter code for Micro-Exercise 2
# Open a new notebook and rename it to 'My First Notebook'.
# This can be done through the file browser.

# %% [markdown]
# ## Examples
# ### Example 1: Creating a New Folder
# This example demonstrates how to create a new folder in the file browser to organize your notebooks.
# ```python
# # Right-click in the file browser and select 'New Folder'.
# ```

# %% [markdown]
# ### Example 2: Opening a Notebook
# This example shows how to open an existing notebook from the file browser.
# ```python
# # Double-click on the notebook file in the file browser.
# ```

# %% [markdown]
# ## Main Exercise
# - **Description:** Create a new folder for your data science project, add a new notebook, and rename it appropriately. Use the file browser to manage your files effectively.

# %%
# Code to create a new folder and notebook
# Create a new folder named 'Data Science Project'.
# Inside this folder, create a new notebook named 'Data Analysis'.

# %% [markdown]
# ## Common Mistakes
# - Not saving notebooks regularly.
# - Overlooking the command palette for quick access to features.

# %% [markdown]
# ## Recap
# In this lesson, we explored the JupyterLab interface, focusing on the file browser and notebook interface. Familiarizing yourself with these tools will enhance your productivity in data science projects. Next, we will dive into creating and executing code within notebooks.
