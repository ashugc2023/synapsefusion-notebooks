# %% [markdown]
# # Creating an AWS Account
#
# In this lesson, you will learn how to create an AWS account, understand different account types, and set up billing alerts to monitor your usage effectively.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lesson, you will be able to:
# - Create an AWS account
# - Understand the different types of AWS accounts
# - Set up billing alerts to monitor usage
# - Recognize the importance of account verification
# - Navigate the account settings

# %% [markdown]
# ## Why This Matters
#
# Creating an AWS account is the first step to accessing AWS services. Without an account, users cannot utilize any AWS resources, which are essential for deploying applications and managing cloud infrastructure.

# %% [markdown]
# ### Key Concept: AWS Account Creation
#
# Creating an AWS account allows users to access a wide range of cloud services. This is crucial for anyone looking to leverage cloud computing for their projects.

# %%
# Example code for creating an AWS account (pseudocode)
# 1. Visit the AWS website
# 2. Click on 'Create an AWS Account'
# 3. Fill in the required information and submit
# 4. Verify your email address
# 5. Set up billing alerts in the account settings

print('Follow the steps above to create your AWS account.')

# %% [markdown]
# ### Micro-Exercise: List the Steps to Create an AWS Account
#
# Write down the steps required to create an AWS account.

# %%
# 1. Visit AWS website
# 2. Click 'Create an AWS Account'
# 3. Fill in information
# 4. Verify email
# 5. Set up billing alerts

# %% [markdown]
# ### Key Concept: Billing Alerts
#
# Billing alerts notify users when their usage approaches a specified limit, helping to manage costs effectively. Setting up billing alerts is essential to avoid unexpected charges.

# %%
# Example code for setting up billing alerts (pseudocode)
# 1. Go to account settings
# 2. Navigate to billing alerts
# 3. Set your alert thresholds

print('Follow the steps above to set up billing alerts in your AWS account.')

# %% [markdown]
# ### Micro-Exercise: Explain How to Set Up Billing Alerts in AWS
#
# Describe the process of setting up billing alerts in your AWS account.

# %%
# 1. Go to account settings
# 2. Navigate to billing alerts
# 3. Set your alert thresholds

# %% [markdown]
# ## Examples
#
# ### Example 1: Creating a Free Tier Account
# This example demonstrates how to create a Free Tier AWS account, which allows users to explore AWS services without incurring costs.

# %%
# Example code for creating a Free Tier account
# 1. Visit the AWS Free Tier page
# 2. Click 'Create a Free Account'
# 3. Follow the prompts to complete the sign-up

print('You have successfully created a Free Tier AWS account.')

# %% [markdown]
# ### Example 2: Setting Up Billing Alerts
# This example shows how to set up billing alerts to monitor usage and avoid unexpected charges.

# %%
# Example code for setting up billing alerts
# 1. Log in to your AWS account
# 2. Go to the Billing Dashboard
# 3. Click on 'Billing Alerts'
# 4. Set your desired thresholds

print('Billing alerts have been set up successfully.')

# %% [markdown]
# ## Micro-Exercises
#
# ### Exercise 1: List the Steps to Create an AWS Account
# Write down the steps required to create an AWS account.

# %% [markdown]
# ### Exercise 2: Explain How to Set Up Billing Alerts in AWS
# Describe the process of setting up billing alerts in your AWS account.

# %% [markdown]
# ## Main Exercise: Create Your AWS Account and Set Up Billing Alerts
# In this exercise, you will create your own AWS account and set up billing alerts to monitor your usage effectively.

# %%
# Step-by-step guide to create an account and set alerts
# 1. Visit the AWS website
# 2. Click on 'Create an AWS Account'
# 3. Fill in the required information and submit
# 4. Verify your email address
# 5. Set up billing alerts in the account settings

print('Follow the steps above to create your AWS account and set up billing alerts.')

# %% [markdown]
# ## Common Mistakes
# - Not verifying email during signup, which can delay access to services.
# - Skipping the billing alerts setup, leading to unexpected charges.

# %% [markdown]
# ## Recap & Next Steps
# In this lesson, you learned how to create an AWS account, understand different account types, and set up billing alerts. In the next lesson, we will explore the AWS Management Console and its features.
