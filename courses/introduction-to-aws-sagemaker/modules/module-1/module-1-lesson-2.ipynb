# %% [markdown]
# # Navigating SageMaker Studio
#
# In this lesson, you will learn how to navigate the SageMaker Studio interface, understand its components, and create and manage Jupyter notebooks.

# %% [markdown]
# ## Learning Objectives
# - Navigate the SageMaker Studio interface effectively
# - Identify key components of the interface
# - Create and manage Jupyter notebooks within SageMaker Studio

# %% [markdown]
# ## Why This Matters
#
# Understanding the SageMaker Studio interface is crucial for efficiently building, training, and deploying machine learning models. A good grasp of the interface allows you to easily access resources, manage projects, and collaborate with others.

# %% [markdown]
# ## SageMaker Studio Interface
# ### Explanation
# The SageMaker Studio interface is a web-based integrated development environment (IDE) that provides a unified interface for building, training, and deploying machine learning models. It includes various tools and features that facilitate the machine learning workflow.

# %%
# Example: Basic navigation in SageMaker Studio
# This code snippet does not run but illustrates how to navigate the interface.
# 1. Open SageMaker Studio from the AWS Management Console.
# 2. Familiarize yourself with the navigation bar, file browser, and code editor.

# %% [markdown]
# ### Micro-Exercise
# Explore the SageMaker Studio interface and identify at least five components.

# %%
# Components of SageMaker Studio
# 1. Component 1: 
# 2. Component 2: 
# 3. Component 3: 
# 4. Component 4: 
# 5. Component 5:

# %% [markdown]
# ## Notebooks in SageMaker
# ### Explanation
# Notebooks in SageMaker are interactive documents that allow users to write and execute code in a flexible environment. They support various programming languages, including Python, and are essential for data exploration, visualization, and model development.

# %%
# Example: Running a simple Python command in a Jupyter notebook
# This code snippet demonstrates running a basic command.
result = 5 + 3
print('The result is:', result)

# %% [markdown]
# ### Micro-Exercise
# Create a new Jupyter notebook and run a simple Python command.

# %%
# Create a new notebook
print('Hello, SageMaker!')

# %% [markdown]
# ## Examples
# ### Example 1: Creating a Notebook for Data Analysis
# This example demonstrates how to create a new Jupyter notebook in SageMaker Studio and run a simple analysis on a dataset.

# %%
# Create a new notebook
import pandas as pd
# Load dataset
data = pd.read_csv('customer_data.csv')
# Display first few rows
print(data.head())

# %% [markdown]
# ### Example 2: Running Python Commands
# This example shows how to run basic Python commands in a Jupyter notebook to perform calculations.

# %%
# Simple Python command
result = 5 + 3
print('The result is:', result)

# %% [markdown]
# ## Main Exercise
# ### Creating and Running a Jupyter Notebook
# In this exercise, you will create a new Jupyter notebook in SageMaker Studio, write Python code to perform a simple data analysis, and run the code to see the results.

# %%
# Create a new notebook
import pandas as pd
# Load dataset
data = pd.read_csv('customer_data.csv')
# Display summary statistics
print(data.describe())

# %% [markdown]
# ## Common Mistakes
# - Not saving work regularly in notebooks
# - Forgetting to install necessary libraries before running code

# %% [markdown]
# ## Recap & Next Steps
# In this lesson, you learned how to navigate the SageMaker Studio interface and create Jupyter notebooks. Next, we will explore how to train machine learning models using SageMaker.
