# %% [markdown]
# # Capstone Project Overview
#
# In this lesson, you will learn about the capstone project, its requirements, and the steps necessary for successful completion. By the end of this lesson, you will be able to define the scope of your project and identify the deliverables needed.
#
# ## Learning Objectives:
# - Understand the project requirements and scope
# - Plan the structure of your project
# - Identify necessary resources for project completion

# %% [markdown]
# ## Why This Matters
#
# Effective project planning ensures that you have a clear roadmap to follow, reducing the risk of missing deadlines or deliverables. Identifying resources early helps ensure you have everything needed to complete the project, including tools, libraries, and support.

# %% [markdown]
# ## Project Planning
#
# Project planning involves outlining the objectives, scope, and timeline of your project. It serves as a roadmap for execution.

# %%
# Example of defining project scope
project_scope = {
    'objectives': ['Build a web app', 'Implement user authentication'],
    'deliverables': ['Prototype', 'Final report']
}

# Display the project scope
print('Project Scope:', project_scope)

# %% [markdown]
# ### Micro-exercise: Define Your Project
#
# Write a brief description of your capstone project. Consider the main objectives and what you want to achieve.

# %%
# Exercise: Define Your Project
# Write a brief description of your capstone project here.
project_description = """
Your project description goes here.
"""
print('Project Description:', project_description)

# %% [markdown]
# ## Resource Identification
#
# Resource identification is the process of determining what tools, libraries, and support you will need to successfully complete your project.

# %%
# Example of listing resources
resources_needed = [
    'Python',
    'Flask',
    'SQLite',
    'GitHub for version control'
]

# Display the resources needed
print('Resources Needed:', resources_needed)

# %% [markdown]
# ### Micro-exercise: Identify Resources
#
# List the resources you will need for your project. Think about both technical and human resources.

# %%
# Exercise: Identify Resources
# List the resources you will need for your project here.
resources = [
    'Your resource 1',
    'Your resource 2'
]
print('Resources:', resources)

# %% [markdown]
# ## Examples
#
# ### Example 1: Defining Project Scope
# This example demonstrates how to clearly define the scope of a project by outlining its objectives and deliverables.

# %%
# Define the scope
project_scope = {
    'objectives': ['Build a web app', 'Implement user authentication'],
    'deliverables': ['Prototype', 'Final report']
}

# Display the project scope
print('Project Scope:', project_scope)

# %% [markdown]
# ### Example 2: Setting Milestones
# This example shows how to set milestones for a project timeline to track progress effectively.

# %%
# Set milestones
milestones = [
    {'phase': 'Planning', 'date': '2023-10-01'},
    {'phase': 'Development', 'date': '2023-11-01'},
    {'phase': 'Testing', 'date': '2023-12-01'}
]

# Display the milestones
print('Milestones:', milestones)

# %% [markdown]
# ## Main Exercise: Comprehensive Project Plan
# Create a detailed project plan for your capstone project, including objectives, timeline, and resource list.

# %%
# Outline your project plan here.
project_plan = {
    'objectives': [],
    'timeline': [],
    'resources': []
}

# Display the project plan
print('Project Plan:', project_plan)

# %% [markdown]
# ## Common Mistakes
# - Not planning adequately, which can lead to project delays.
# - Overcomplicating the project scope, making it difficult to manage.

# %% [markdown]
# ## Recap & Next Steps
# In this lesson, you learned about the importance of project planning and resource identification for your capstone project. As you move forward, ensure that you have a clear project plan and the necessary resources to succeed.
