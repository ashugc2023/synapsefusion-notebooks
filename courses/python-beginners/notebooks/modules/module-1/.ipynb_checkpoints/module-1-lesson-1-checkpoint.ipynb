# %% [markdown]
# # Setting Up Python and JupyterLab
#
# In this lesson, you will learn how to install Python and JupyterLab, and understand the interface of JupyterLab to start coding in Python.
#
# ## Learning Objectives
# - Install Python on your computer.
# - Install JupyterLab using pip.
# - Navigate the JupyterLab interface.

# %% [markdown]
# ## Why This Matters
#
# Installing Python is the first step in your programming journey, allowing you to run Python code on your machine. JupyterLab provides an interactive environment for writing and executing Python code, making it easier to visualize results.

# %% [markdown]
# ## Key Concept: Python Installation
#
# Python is a versatile programming language that is widely used for various applications, including web development, data analysis, and artificial intelligence. Installing Python on your computer allows you to write and execute Python code locally.

# %%
# Example: Installing Python
# Follow the installation wizard after downloading Python from the official website.
# No code snippet needed for installation.

# %% [markdown]
# ### Micro-Exercise 1
#
# **Exercise:** Open a terminal and type `python --version` to check if Python is installed correctly.
#
# **Hint:** Make sure you are using the correct command for your operating system.

# %%
# Micro-Exercise 1 Starter Code
# Check Python version
# !python --version

# %% [markdown]
# ## Key Concept: JupyterLab Interface
#
# JupyterLab is an interactive development environment that allows you to create and manage Jupyter notebooks, which are documents that can contain live code, equations, visualizations, and narrative text.

# %%
# Example: Creating a Jupyter Notebook
# Create a new Jupyter notebook and run the following command:
print('Hello, World!')

# %% [markdown]
# ### Micro-Exercise 2
#
# **Exercise:** Create a new Jupyter notebook and add a markdown cell with your name.
#
# **Hint:** Use the markdown cell to format your name as a heading.

# %%
# Micro-Exercise 2 Starter Code
# Create a new Jupyter notebook and add your name
name = 'Your Name'
print(f'Hello, {name}!')

# %% [markdown]
# ## Examples Section
#
# ### Example 1: Installing Python
# This example demonstrates how to download and install Python on your computer. Follow the installation wizard after downloading Python from the official website.
#
# ### Example 2: Creating a Jupyter Notebook
# This example shows how to create a new Jupyter notebook and run a simple Python command:
# ```python
# print('Hello, World!')
# ```

# %% [markdown]
# ## Micro-Exercises Section
#
# ### Exercise 1: Verify Python Installation
# Open a terminal and type `python --version` to check if Python is installed correctly.
#
# ### Exercise 2: Create Your First Notebook
# Create a new Jupyter notebook and add a markdown cell with your name.

# %% [markdown]
# ## Main Exercise
# In this exercise, you will download and install Python, install JupyterLab, and create a new notebook where you will write and execute a simple Python script.
#
# ### Starter Code:
# ```python
# # Create a new Jupyter notebook and write the following code:
# print('Hello, World!')
# ```
#
# ### Expected Outcomes:
# - Successfully installed Python and JupyterLab.
# - Created a new Jupyter notebook and executed a Python script.

# %%
# Main Exercise Starter Code
# Write a simple Python script
print('This is my first Python script in JupyterLab!')

# %% [markdown]
# ## Common Mistakes
# - Skipping installation steps or not following instructions carefully.
# - Not checking if Python is added to the system PATH during installation.

# %% [markdown]
# ## Recap
# In this lesson, you learned how to install Python and JupyterLab, and how to navigate the JupyterLab interface. In the next lesson, we will dive into writing your first Python scripts and understanding basic syntax.
